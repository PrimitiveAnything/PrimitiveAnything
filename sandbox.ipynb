# %%
from volumetricPrimitivesPytorch.data.shapenet import R2N2ShapeNetDataset

dataset = R2N2ShapeNetDataset(r2n2_shapenet_dir='data/r2n2_shapenet')
# Out:
# /home/sarambulo/miniconda3/envs/3d-learning/lib/python3.12/site-packages/pytorch3d/datasets/shapenet/shapenet_core.py:116: UserWarning: The following categories are included in ShapeNetCore ver.1's official mapping but not found in the dataset location data/r2n2_shapenet/shapenet: 04530566, 03797390, 03691459, 04099429, 02747177, 03207941, 02880940, 04256520, 03710193, 02871439, 04074963, 04004475, 02834778, 02942699, 02691156, 02946921, 04401088, 04460130, 02843684, 03046257, 02808440, 03325088, 04379243, 04468005, 03624134, 02818832, 02992529, 02858304, 03790512, 02876657, 03991062, 02773838, 03636649, 03261776, 03467517, 02954340, 02933112, 02924116, 02801938, 02958343, 03211117, 04090263, 03938244, 04330267, 03928116, 03642806, 03759954, 03948459, 03593526, 02828884, 03337140, 03513137, 04225987, 03761084, 03085013, 04554684
#   warnings.warn(msg)
# ...

# %%
len(dataset.shapenet_dataset)
# Out:
# 6778

# %%
len(dataset.r2n2_dataset)
# Out:
# 6100

# %%
x_s, x_r = dataset[0]

# %%
x_s.keys()
# Out:
# dict_keys(['synset_id', 'model_id', 'verts', 'faces', 'textures', 'label'])

# %%
print('synset_id: ', x_s['synset_id'])
print('model_id: ', x_s['model_id'])
print('label: ', x_s['model_id'])
print('verts shape and dtype: ', x_s['verts'].shape, x_s['verts'].dtype)
print('faces shape and dtype: ', x_s['faces'].shape, x_s['faces'].dtype)
print('textures shape and dtype: ', x_s['textures'].shape, x_s['textures'].dtype)
# Out:
# synset_id:  03001627
# model_id:  4a671498c6e96238bf8db636a3460ee5
# label:  4a671498c6e96238bf8db636a3460ee5
# verts shape and dtype:  torch.Size([19758, 3]) torch.float32
# faces shape and dtype:  torch.Size([84074, 3]) torch.int64
# textures shape and dtype:  torch.Size([84074, 4, 4, 3]) torch.float32

# %%
x_r.keys()
# Out:
# dict_keys(['synset_id', 'model_id', 'verts', 'faces', 'textures', 'label', 'images', 'R', 'T', 'K', 'voxels'])

# %%
print('synset_id: ', x_r['synset_id'])
print('model_id: ', x_r['model_id'])
print('label: ', x_r['model_id'])
print('verts shape and dtype: ', x_r['verts'].shape, x_r['verts'].dtype)
print('faces shape and dtype: ', x_r['faces'].shape, x_r['faces'].dtype)
print('textures shape and dtype: ', x_r['textures'].shape, x_r['textures'].dtype)
print('images shape and dtype: ', x_r['images'].shape, x_r['images'].dtype)
print('R shape and dtype: ', x_r['R'].shape, x_r['R'].dtype)
print('T shape and dtype: ', x_r['T'].shape, x_r['T'].dtype)
print('K shape and dtype: ', x_r['K'].shape, x_r['K'].dtype)
print('voxels shape and dtype: ', x_r['voxels'].shape, x_r['voxels'].dtype)
# Out:
# synset_id:  03001627
# model_id:  d8e2e2a923b372731cf97e154cc62f43
# label:  d8e2e2a923b372731cf97e154cc62f43
# verts shape and dtype:  torch.Size([58, 3]) torch.float32
# faces shape and dtype:  torch.Size([224, 3]) torch.int64
# textures shape and dtype:  torch.Size([224, 4, 4, 3]) torch.float32
# images shape and dtype:  torch.Size([10, 137, 137, 3]) torch.float32
# R shape and dtype:  torch.Size([10, 3, 3]) torch.float32
# T shape and dtype:  torch.Size([10, 3]) torch.float32
# K shape and dtype:  torch.Size([10, 4, 4]) torch.float32
# voxels shape and dtype:  torch.Size([10, 128, 128, 128]) torch.uint8

# %%
# Out:
# tensor([[[True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          ...,
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True]],
#
#         [[True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          ...,
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True]],
#
#         [[True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
#          ...,
#          [True, True, True,  ..., True, True, True],
#          [True, True, True,  ..., True, True, True],
# ...
